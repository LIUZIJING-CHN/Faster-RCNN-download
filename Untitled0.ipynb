# %% [markdown]
# <a href="https://colab.research.google.com/github/LIUZIJING-CHN/Faster-RCNN-download/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Out:
# --2020-07-09 07:32:47--  http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... ^C

# %%
# !tar xvf VOCtrainval_11-May-2012.tar

# %%
# !git clone https://github.com/alicranck/instance-seg.git
# Out:
# Cloning into 'instance-seg'...
# remote: Enumerating objects: 175, done.
# remote: Total 175 (delta 0), reused 0 (delta 0), pack-reused 175
# Receiving objects: 100% (175/175), 1.92 MiB | 2.07 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
# !python train.py
# Out:
# 2020-07-09 07:50:25,880 test_05      WARNING  checkpoint does not exist. creating new experiment
# 2020-07-09 07:50:27,063 test_05      INFO     training started/resumed at epoch 0
# Using CUDA
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.
# 2020-07-09 07:50:32,163 test_05      INFO     epoch: 0, batch number: 0, loss: 39.57
# 2020-07-09 07:50:33,290 test_05      INFO     epoch: 0, batch number: 1, loss: 33.04
# 2020-07-09 07:50:34,412 test_05      INFO     epoch: 0, batch number: 2, loss: 25.41
# 2020-07-09 07:50:35,639 test_05      INFO     epoch: 0, batch number: 3, loss: 21.22
# ...
